# %%
#import required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import warnings
warnings.filterwarnings('ignore')

# %%
years = ['1930s','1940s','1950s']
movies = []
for year in years:
    url = "https://en.wikipedia.org/wiki/List_of_Kannada_films_of_the_" + year
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    current_year = None
    
    for tag in soup.find_all(['h2', 'table']):
        # If it's an h2 tag, try to find the year inside it
        if tag.name == 'h2':
            year_match = re.search(r'\b(195\d)\b', tag.get_text())
            if year_match:
                current_year = year_match.group(1)
            # If it's a wikitable, extract it and add the current year
        elif tag.name == 'table' and 'wikitable' in tag.get('class', []):
            df = pd.read_html(str(tag))[0]
            if current_year:
                df['Year'] = current_year
                print(current_year)     
            df['Language'] = 'Kannada'
            df['url'] = url
            movies.append(df)
# Out:
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959

# %%
# year 1960 - 2025
years = list(range(1960, 2026))
for year in years:
    url = "https://en.wikipedia.org/wiki/List_of_Kannada_films_of_" + str(year)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    tables = soup.find_all('table', {'class': 'wikitable'})
    print(len(tables))
    for table in tables:
        df = pd.read_html(str(table))[0]
        col_names = [str(col).lower().strip() for col in df.columns]
        print(col_names)
        if "title" in col_names and "director" in col_names and 'cast' in col_names:
            df['Year'] = year
            df['Language'] = "Kannada"
            df['url'] = url
            movies.append(df)
            print(url)
# Out:
# 2
# ['0', '1']
# ['title', 'director', 'cast', 'music director', 'producer', 'banner']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1960
# 2
# ['0', '1']
# ['title', 'director', 'cast', 'music director', 'producer', 'banner']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1961
# 1
# ['title', 'director', 'cast', 'music director', 'producer']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1962
# 1
# ['title', 'director', 'cast', 'music director', 'producer']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1963
# 1
# ['title', 'director', 'cast', 'music director', 'producer']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1964
# 1
# ['title', 'director', 'cast', 'music director', 'producer']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1965
# 1
# ['title', 'director', 'cast', 'music director', 'producer']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1966
# 1
# ['title', 'director', 'cast', 'music director', 'producer']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1967
# 1
# ['title', 'director', 'cast', 'music director', 'producer']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1968
# 1
# ['title', 'director', 'cast', 'music director', 'producer']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1969
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1970
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1971
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1972
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1973
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1974
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1975
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1976
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1977
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1978
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1979
# 1
# ['title', 'director', 'cast', 'music director', 'producer', 'cinematographer']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1980
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1981
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1982
# 1
# ['title', 'director', 'cast', 'music', 'reference']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1983
# 1
# ['title', 'director', 'cast', 'music', 'reference']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1984
# 1
# ['title', 'director', 'cast', 'music', 'reference']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1985
# 1
# ['title', 'director', 'cast', 'music', 'reference']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1986
# 1
# ['title', 'director', 'cast', 'music', 'reference']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1987
# 1
# ['title', 'director', 'cast', 'music', 'reference']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1988
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1989
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1990
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1991
# 1
# ['title', 'director', 'cast', 'music', 'reference']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1992
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1993
# 1
# ['title', 'title in kannada', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1994
# 1
# ['title', 'title in kannada', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1995
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1996
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1997
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1998
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_1999
# 1
# ['title', 'director', 'cast', 'music']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2000
# 1
# ['title', 'director', 'cast', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2001
# 1
# ['title', 'director', 'cast', 'music', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2002
# 2
# ['month', 'title', 'director', 'cast', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2003
# ['month', 'title', 'director', 'cast', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2003
# 2
# ['opening', 'opening.1', 'title', 'director', 'cast', 'music director', 'genre', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2004
# ['opening', 'opening.1', 'title', 'director', 'cast', 'music director', 'genre', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2004
# 2
# ['opening', 'opening.1', 'title', 'director', 'cast', 'music director', 'genre', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2005
# ['opening', 'opening.1', 'title', 'director', 'cast', 'music director', 'genre', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2005
# 2
# ['opening', 'opening.1', 'title', 'director', 'cast', 'music director', 'genre', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2006
# ['opening', 'opening.1', 'title', 'director', 'cast', 'music director', 'genre', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2006
# 1
# ['month', 'title', 'director', 'cast', 'music', 'other notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2007
# 1
# ['month', 'title', 'director', 'cast', 'music', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2008
# 2
# ['rank', 'title', 'production company', 'worldwide gross', 'ref']
# ['month', 'title', 'director', 'cast', 'music', 'genre', 'ref.']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2009
# 3
# ['opening', 'opening.1', 'title', 'director', 'cast', 'music director', 'genre', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2010
# ['opening', 'opening.1', 'title', 'director', 'cast', 'music director', 'genre', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2010
# ['0', '1', '2', '3', '4', '5', '6']
# 4
# ['rank', 'title', 'production company', 'worldwide gross', 'references']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'music director', 'genre', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2011
# ['opening', 'opening.1', 'title', 'director', 'cast', 'music director', 'genre', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2011
# ['0', '1', '2', '3', '4', '5']
# 4
# ['rank', 'title', 'production company', 'worldwide gross', 'references']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2012
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'notes']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2012
# ['0', '1', '2', '3', '4', '5']
# 4
# ['rank', 'title', 'production company', 'worldwide gross', 'references']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2013
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2013
# ['0', '1', '2', '3', '4', '5']
# 4
# ['rank', 'title', 'production company', 'worldwide gross', 'references']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2014
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2014
# ['month', 'date', 'name', 'age', 'sex', 'profession', 'notable work']
# 4
# ['rank', 'title', 'production company', 'worldwide gross', 'references']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2015
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2015
# ['month', 'date', 'name', 'age', 'sex', 'profession', 'notable work']
# 3
# ['rank', 'title', 'production company', 'worldwide gross', 'references']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2016
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2016
# 3
# ['rank', 'title', 'production company', 'worldwide gross', 'ref']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2017
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref', '#']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2017
# 3
# ['rank', 'title', 'production company', 'worldwide gross', 'ref']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2018
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2018
# 5
# ['rank', 'title', 'production company', 'worldwide gross', 'references']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2019
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2019
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2019
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2019
# 3
# ['rank', 'title', 'production company', 'gross', 'ref.']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2020
# ['opening', 'opening.1', 'title', 'director', 'cast', 'notes', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2020
# 5
# ['rank', 'title', 'gross', 'production company', 'ref.']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2021
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref', 'unnamed: 7']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2021
# ['opening', 'opening.1', 'title', 'director', 'cast', 'note', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2021
# ['opening', 'opening.1', 'title', 'director', 'cast', 'note', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2021
# 5
# ['rank', 'title', 'production company', 'gross', 'ref.']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2022
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2022
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref.']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2022
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref.']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2022
# 5
# ['rank', 'title', 'production company', 'gross', 'ref']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2023
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2023
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2023
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref.']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2023
# 5
# ['rank', 'title', 'production company', 'worldwide gross', 'ref']
# ['opening', 'opening.1', 'title', 'director', 'main cast', 'production company', 'ref.']
# ['opening', 'opening.1', 'title', 'director', 'main cast', 'production company', 'ref.']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2024
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2024
# 6
# ['rank', 'title', 'production company', 'worldwide gross', 'ref']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref.']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2025
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref.']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2025
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref.']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2025
# ['opening', 'opening.1', 'title', 'director', 'cast', 'studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2025
# ['title', 'director', 'cast', 'production company', 'ref.']
# https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2025

# %%
df = pd.concat(movies, ignore_index=True)

# %%
df
# Out:
#       Year                        Title                Director  \
# 0     1934               Sati Sulochana               Y. V. Rao
# 1     1934                Bhakta Dhruva    Parshwanatha Altekar
# 2     1935                    Sadaarame      Raja Chandrashekar
# 3     1936                Samsara Nauka          H. L. N. Simha
# 4     1936                  Chiranjeevi             K. P. Bhave
# ...    ...                          ...                     ...
# 4812  2025                     Rachayya            Jadesh Hampi
# 4813  2025                     Ramarasa           B. M. Giriraj
# 4814  2025              Richard Anthony          Rakshit Shetty
# 4815  2025  Theertharoopa Tandeyavarige  Ramenahalli Jagannatha
# 4816  2025         Yours Sincerely Raam          Vikhyath A. R.
#
#                                                    Cast  \
# 0     R. Nagendra Rao, Tripuramba, Subbaiah Naidu, L...
# 1     Master Muthu, G. Nagesha Rao, T. Kanakalakshma...
# 2     Gubbi Veeranna, K.Ashwathamma, Muraaraachaar, ...
# 3     B. R. Panthulu, M. V. Rajamma, S. K. Padma Dev...
# 4     Devudu Narasimha Sastri, Sharada, Master Naray...
# ...                                                 ...
# 4812           Duniya Vijay, Rachita Ram, Raj B. Shetty
# 4813                                     Karthik Mahesh
# 4814                                     Rakshit Shetty
# 4815                                       Nihar Mukesh
# 4816                             Ganesh, Ramesh Aravind
#
#                                 Music Director            Producer  \
# 0     R. Nagendra Rao H. R. Padmanabha Shastry  Chamanlal Doongaji
# 1                      Harmonium Sheshagirirao  U. L. Narayana Rao
# 2                     Venkataramaiah (Papanna)      Gubbi Veeranna
# 3                                M. Madhavarao         K. Nanjappa
# 4                      Harmonium Sheshagirirao                 NaN
# ...                                        ...                 ...
# 4812                                       NaN                 NaN
# 4813                                       NaN                 NaN
# 4814                                       NaN                 NaN
# 4815                                       NaN                 NaN
# 4816                                       NaN                 NaN
#
#                      Banner Language  \
# 0     South India Movietone  Kannada
# 1          Jayavani Talkies  Kannada
# 2          Shakuntala Films  Kannada
# 3                Devi Films  Kannada
# 4          Canarese Talkies  Kannada
# ...                     ...      ...
# 4812                    NaN  Kannada
# 4813                    NaN  Kannada
# 4814                    NaN  Kannada
# 4815                    NaN  Kannada
# 4816                    NaN  Kannada
#
#                                                     url Director(s)  ...  \
# 0     https://en.wikipedia.org/wiki/List_of_Kannada_...         NaN  ...
# 1     https://en.wikipedia.org/wiki/List_of_Kannada_...         NaN  ...
# 2     https://en.wikipedia.org/wiki/List_of_Kannada_...         NaN  ...
# 3     https://en.wikipedia.org/wiki/List_of_Kannada_...         NaN  ...
# 4     https://en.wikipedia.org/wiki/List_of_Kannada_...         NaN  ...
# ...                                                 ...         ...  ...
# 4812  https://en.wikipedia.org/wiki/List_of_Kannada_...         NaN  ...
# 4813  https://en.wikipedia.org/wiki/List_of_Kannada_...         NaN  ...
# 4814  https://en.wikipedia.org/wiki/List_of_Kannada_...         NaN  ...
# 4815  https://en.wikipedia.org/wiki/List_of_Kannada_...         NaN  ...
# 4816  https://en.wikipedia.org/wiki/List_of_Kannada_...         NaN  ...
#
#      Opening.1 Genre Other notes Ref.  Ref   # Studio Unnamed: 7 Note  \
# 0          NaN   NaN         NaN  NaN  NaN NaN    NaN        NaN  NaN
# 1          NaN   NaN         NaN  NaN  NaN NaN    NaN        NaN  NaN
# 2          NaN   NaN         NaN  NaN  NaN NaN    NaN        NaN  NaN
# 3          NaN   NaN         NaN  NaN  NaN NaN    NaN        NaN  NaN
# 4          NaN   NaN         NaN  NaN  NaN NaN    NaN        NaN  NaN
# ...        ...   ...         ...  ...  ...  ..    ...        ...  ...
# 4812       NaN   NaN         NaN  NaN  NaN NaN    NaN        NaN  NaN
# 4813       NaN   NaN         NaN  NaN  NaN NaN    NaN        NaN  NaN
# 4814       NaN   NaN         NaN  NaN  NaN NaN    NaN        NaN  NaN
# 4815       NaN   NaN         NaN  NaN  NaN NaN    NaN        NaN  NaN
# 4816       NaN   NaN         NaN  NaN  NaN NaN    NaN        NaN  NaN
#
#                   Production company
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 4812                   Sarathi Films
# 4813                       G Cinemas
# 4814                   Hombale Films
# 4815  Jai Chamundeshwari Productions
# 4816              The Rayala Studios
#
# [4817 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Title', 'Director', 'Cast', 'Music Director', 'Producer',
#        'Banner', 'Language', 'url', 'Director(s)', 'Production House', 'Film',
#        'Music director', 'Music', 'Cinematographer', 'Reference',
#        'Title in Kannada', 'Notes', 'Month', 'Opening', 'Opening.1', 'Genre',
#        'Other notes', 'Ref.', 'Ref', '#', 'Studio', 'Unnamed: 7', 'Note',
#        'Production company'],
#       dtype='object')

# %%
# keep non null values from all columns, row by row
df['music'] = df[['Music Director', 'Music director', 'Music']].bfill(axis=1).iloc[:, 0]
df['production'] = df[['Production House', 'Production company']].bfill(axis=1).iloc[:, 0]
df['ref'] = df[['Reference', 'Ref.', 'Ref']].bfill(axis=1).iloc[:, 0]
df['title'] = df[['Title', 'Film']].bfill(axis=1).iloc[:, 0]

# %%
df = df[['title', 'Director', 'Cast', 'Year', 'Language', 'url', 'Producer','Genre', 'production', 'music', 'ref']]

# %%
df.columns = ['Title', 'Director', 'Cast', 'Year', 'Language', 'url', 'Producer','Genre', 'production', 'music', 'ref']

# %%
df.to_csv("kannada_movies_1930_2025.csv", index=False)
