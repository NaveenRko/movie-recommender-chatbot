# %%
#import required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import warnings
warnings.filterwarnings('ignore')

# %%
# year 1930-39
url = "https://en.wikipedia.org/wiki/List_of_Tamil_films_of_the_1930s"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
movies = []
current_year = None

for tag in soup.find_all(['h2', 'table']):
    # If it's an h2 tag, try to find the year inside it
    if tag.name == 'h2':
        year_match = re.search(r'\b(193\d)\b', tag.get_text())
        if year_match:
            current_year = year_match.group(1)
            
    # If it's a wikitable, extract it and add the current year
    elif tag.name == 'table' and 'wikitable' in tag.get('class', []):
        df = pd.read_html(str(tag))[0]
        if current_year:
            df['Year'] = current_year
        df['Language'] = 'Tamil'
        df['url'] = url
        movies.append(df)
        print(current_year)
# Out:
# 1931
# 1932
# 1933
# 1934
# 1935
# 1936
# 1937
# 1938
# 1939

# %%
# year 1940 - 2025
years = list(range(1940, 2026))
for year in years:
    url = "https://en.wikipedia.org/wiki/List_of_Tamil_films_of_" + str(year)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    tables = soup.find_all('table', {'class': 'wikitable'})
    for table in tables:
        df = pd.read_html(str(table))[0]
        col_names = [str(col).lower().strip() for col in df.columns]
        if "title" in col_names and "director" in col_names and 'cast' in col_names:
            df['Year'] = year
            df['Language'] = "Tamil"
            df['url'] = url
            movies.append(df)
            print(url)
# Out:
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1940
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1941
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1942
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1943
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1944
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1945
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1946
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1947
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1948
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1949
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1950
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1951
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1952
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1953
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1954
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1955
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1956
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1957
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1958
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1959
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1960
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1961
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1962
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1963
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1964
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1965
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1966
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1967
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1968
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1969
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1970
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1971
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1972
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1973
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1974
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1975
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1976
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1977
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1978
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1979
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1980
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1981
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1982
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1983
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1984
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1985
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1986
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1987
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1988
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1989
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1990
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1991
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1992
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1992
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1992
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1992
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1993
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1994
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1994
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1994
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1994
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1995
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1996
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1997
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1997
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1997
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1997
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1998
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1998
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1998
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1998
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1999
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1999
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1999
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_1999
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2000
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2000
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2000
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2000
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2000
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2001
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2001
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2001
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2001
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2001
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2002
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2002
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2002
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2002
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2002
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2003
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2003
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2003
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2003
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2003
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2004
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2004
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2004
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2004
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2004
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2005
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2005
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2005
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2005
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2005
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2006
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2006
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2006
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2006
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2007
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2007
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2007
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2007
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2007
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2008
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2008
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2008
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2008
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2008
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2009
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2009
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2009
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2009
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2010
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2010
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2010
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2010
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2011
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2012
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2012
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2013
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2013
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2013
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2013
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2014
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2014
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2015
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2015
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2016
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2016
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2017
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2017
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2017
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2017
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2018
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2018
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2018
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2018
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2019
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2019
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2019
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2019
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2020
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2020
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2020
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2020
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2021
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2021
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2021
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2021
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2022
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2022
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2022
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2023
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2023
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2023
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2023
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2024
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2024
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2024
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2024
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2025
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2025
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2025
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2025
# https://en.wikipedia.org/wiki/List_of_Tamil_films_of_2025

# %%
df = pd.concat(movies, ignore_index=True)

# %%
df.head()
# Out:
#                                  Title  \
# 0                              Kalidas
# 1  Harichandra (Sampoorna Harichandra)
# 2                 Kalava (Galavarishi)
# 3           Paarijaatha Pushpaha ragam
# 4                            Ramayanam
#
#                                    Director  \
# 0                               H. M. Reddy
# 1  Sarvottam Badami, T. C. Vadivelu Naicker
# 2                          P. B. Rangachari
# 3                         P. K. Raja Sandow
# 4                                       NaN
#
#                            Production                     Music  \
# 0                      Ardeshir Irani  Madhurakavi Bhaskara Das
# 1  Sagar Film Company Chimanlal Desai         Raja Chandrasekar
# 2                  Sagar Film Company    G. Sundara Bhagavathar
# 3               Imperial Film Company                       NaN
# 4             East India Film Company                       NaN
#
#                                                 Cast  Year Language  \
# 0  T. P. Rajalakshmi, P. G. Venkatesan, L. V. Prasad  1931    Tamil
# 1  V. S Sunderasa Iyer, D. R. Muthulakshmi, T. P....  1932    Tamil
# 2  P. B. Rangachari, V. S. Sunderasa Iyer, T. R. ...  1932    Tamil
# 3  R. Nagendra Rao, K. T. Rukmani, Leela, Narasmi...  1932    Tamil
# 4                      T. P. Rajalakshmi, T. S. Mani  1932    Tamil
#
#                                                  url Release date (D-M-Y)  \
# 0  https://en.wikipedia.org/wiki/List_of_Tamil_fi...                  NaN
# 1  https://en.wikipedia.org/wiki/List_of_Tamil_fi...                  NaN
# 2  https://en.wikipedia.org/wiki/List_of_Tamil_fi...                  NaN
# 3  https://en.wikipedia.org/wiki/List_of_Tamil_fi...                  NaN
# 4  https://en.wikipedia.org/wiki/List_of_Tamil_fi...                  NaN
#
#   Release date  ... Ref. Studio Music director Genre Notes Production Studio  \
# 0          NaN  ...  NaN    NaN            NaN   NaN   NaN               NaN
# 1          NaN  ...  NaN    NaN            NaN   NaN   NaN               NaN
# 2          NaN  ...  NaN    NaN            NaN   NaN   NaN               NaN
# 3          NaN  ...  NaN    NaN            NaN   NaN   NaN               NaN
# 4          NaN  ...  NaN    NaN            NaN   NaN   NaN               NaN
#
#   Unnamed: 6 Ref.(s) Production company Production Company
# 0        NaN     NaN                NaN                NaN
# 1        NaN     NaN                NaN                NaN
# 2        NaN     NaN                NaN                NaN
# 3        NaN     NaN                NaN                NaN
# 4        NaN     NaN                NaN                NaN
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Title', 'Director', 'Production', 'Music', 'Cast', 'Year', 'Language',
#        'url', 'Release date (D-M-Y)', 'Release date', 'Producer', 'Opening',
#        'Opening.1', 'Ref', 'Date', 'Music Director', 'Ref.', 'Studio',
#        'Music director', 'Genre', 'Notes', 'Production Studio', 'Unnamed: 6',
#        'Ref.(s)', 'Production company', 'Production Company'],
#       dtype='object')

# %%
# keep non null values from all columns, row by row
df['music'] = df[['Music', 'Music Director', 'Music director']].bfill(axis=1).iloc[:, 0]
df['production'] = df[['Production', 'Studio', 'Production Studio', 'Production company', 'Production Company']].bfill(axis=1).iloc[:, 0]
df['release'] = df[['Release date (D-M-Y)', 'Release date', 'Date']].bfill(axis=1).iloc[:, 0]
df['ref'] = df[['Ref', 'Ref.', 'Ref.(s)']].bfill(axis=1).iloc[:, 0]

# %%
df = df[['Title', 'Director', 'Cast', 'Year', 'Language', 'url', 'Producer','Genre', 'production', 'music', 'release', 'ref']]

# %%
df
# Out:
#                                     Title  \
# 0                                 Kalidas
# 1     Harichandra (Sampoorna Harichandra)
# 2                    Kalava (Galavarishi)
# 3              Paarijaatha Pushpaha ragam
# 4                               Ramayanam
# ...                                   ...
# 7707                            The Proof
# 7708                              Titanic
# 7709                                Train
# 7710                       Vaa Vaathiyaar
# 7711              Yezhu Kadal Yezhu Malai
#
#                                       Director  \
# 0                                  H. M. Reddy
# 1     Sarvottam Badami, T. C. Vadivelu Naicker
# 2                             P. B. Rangachari
# 3                            P. K. Raja Sandow
# 4                                          NaN
# ...                                        ...
# 7707                                 I.Radhika
# 7708                            M. Janakiraman
# 7709                                   Mysskin
# 7710                          Nalan Kumarasamy
# 7711                                       Ram
#
#                                                    Cast  Year Language  \
# 0     T. P. Rajalakshmi, P. G. Venkatesan, L. V. Prasad  1931    Tamil
# 1     V. S Sunderasa Iyer, D. R. Muthulakshmi, T. P....  1932    Tamil
# 2     P. B. Rangachari, V. S. Sunderasa Iyer, T. R. ...  1932    Tamil
# 3     R. Nagendra Rao, K. T. Rukmani, Leela, Narasmi...  1932    Tamil
# 4                         T. P. Rajalakshmi, T. S. Mani  1932    Tamil
# ...                                                 ...   ...      ...
# 7707  Sai Dhanshika, Rudhvir Vadhan, Ashok Kumar Bal...  2025    Tamil
# 7708  Kalaiyarasan, Anandhi, Kaali Venkat, Ashna Zaveri  2025    Tamil
# 7709  Vijay Sethupathi, Nassar, Shruti Haasan, Yugi ...  2025    Tamil
# 7710        Karthi, Krithi Shetty, Sathyaraj, Anandaraj  2025    Tamil
# 7711                         Nivin Pauly, Soori, Anjali  2025    Tamil
#
#                                                     url Producer Genre  \
# 0     https://en.wikipedia.org/wiki/List_of_Tamil_fi...      NaN   NaN
# 1     https://en.wikipedia.org/wiki/List_of_Tamil_fi...      NaN   NaN
# 2     https://en.wikipedia.org/wiki/List_of_Tamil_fi...      NaN   NaN
# 3     https://en.wikipedia.org/wiki/List_of_Tamil_fi...      NaN   NaN
# 4     https://en.wikipedia.org/wiki/List_of_Tamil_fi...      NaN   NaN
# ...                                                 ...      ...   ...
# 7707  https://en.wikipedia.org/wiki/List_of_Tamil_fi...      NaN   NaN
# 7708  https://en.wikipedia.org/wiki/List_of_Tamil_fi...      NaN   NaN
# 7709  https://en.wikipedia.org/wiki/List_of_Tamil_fi...      NaN   NaN
# 7710  https://en.wikipedia.org/wiki/List_of_Tamil_fi...      NaN   NaN
# 7711  https://en.wikipedia.org/wiki/List_of_Tamil_fi...      NaN   NaN
#
#                               production                     music release  \
# 0                         Ardeshir Irani  Madhurakavi Bhaskara Das     NaN
# 1     Sagar Film Company Chimanlal Desai         Raja Chandrasekar     NaN
# 2                     Sagar Film Company    G. Sundara Bhagavathar     NaN
# 3                  Imperial Film Company                       NaN     NaN
# 4                East India Film Company                       NaN     NaN
# ...                                  ...                       ...     ...
# 7707                      Golden Studios                       NaN     NaN
# 7708          Thirukumaran Entertainment                       NaN     NaN
# 7709                         V Creations                       NaN     NaN
# 7710                        Studio Green                       NaN     NaN
# 7711                 V House Productions                       NaN     NaN
#
#         ref
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 7707  [194]
# 7708  [195]
# 7709  [196]
# 7710  [197]
# 7711  [198]
#
# [7712 rows x 12 columns]

# %%
df.isnull().sum().sort_values(ascending = True)
# Out:
# Year             0
# Language         0
# url              0
# Title           45
# Director       174
# Cast           180
# production    2853
# music         4826
# ref           4902
# Producer      6060
# Genre         6587
# release       7067
# dtype: int64

# %%
df.to_csv("tamil_movies_1930_2025.csv", index=False)
