# %%
#import required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import warnings
warnings.filterwarnings('ignore')

# %%
# Before 1960
movies = []
url = "https://en.wikipedia.org/wiki/List_of_Malayalam_films_before_1960"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
tables = soup.find_all('table', {'class': 'wikitable'})
print(len(tables))
x = 0
for table in tables:
    df = pd.read_html(str(table))[0]
    df['Language'] = "Malayalam"
    df['url'] = url
    movies.append(df)
    print(url)
# Out:
# 2
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_before_1960
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_before_1960

# %%
# year 1960 - 2025
# skipped year 2000 due error in scraping
years = list(range(1960, 2026))
for year in years:
    if year != 2000:
        url = "https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_" + str(year)
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        tables = soup.find_all('table', {'class': 'wikitable'})
        # print(len(tables))
        for table in tables:
            df = pd.read_html(str(table))[0]
            col_names = [str(col).lower().strip() for col in df.columns]
            # print(col_names)
            if ("title" in col_names or "film" in col_names) and "director" in col_names and ('cast' in col_names or 'cast(s)' in col_names):
                df['Year'] = year
                df['Language'] = "Malayalam"
                df['url'] = url
                movies.append(df)
                print(url)
# Out:
# 1
# ['opening', 'opening.1', 'sl. no.', 'title', 'director', 'story', 'cast(s)', 'music director']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1960
# 1
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1961
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1962
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'basic language', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1962
# 1
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1963
# 1
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1964
# 1
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1965
# 1
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1966
# 1
# ['opening', 'opening.1', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1967
# 1
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1968
# 1
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1969
# 1
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1970
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1971
# ['sl no', 'movies', 'date', 'director', 'story', 'screenplay', 'main actors', 'basic language', 'notes']
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1972
# ['sl no', 'date', 'movies', 'director', 'story', 'screenplay', 'main actors', 'basic language', 'notes']
# 1
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1973
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1974
# ['movie', 'director', 'cast', 'music', 'lyrics']
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1975
# ['movie', 'director', 'cast', 'music', 'lyrics', 'unnamed: 5']
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1976
# ['movie', 'direction', 'actors', 'music', 'lyrics']
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1977
# ['movie', 'direction', 'actors', 'music', 'lyrics']
# 1
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1978
# 1
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1979
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'lyricist', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1980
# ["('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1981
# ["('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1982
# ['film', 'direction', 'story', 'screenplay', 'main actors']
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'lyricist', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1983
# ['film', 'direction', 'story', 'screenplay', 'main actors']
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1984
# ['film', 'direction', 'story', 'screenplay', 'main actors']
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1985
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 2
# ['opening', 'opening.1', 'sl. no.', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1986
# ['movie', 'direction', 'story', 'screenplay', 'main actors']
# 2
# ['opening', 'opening.1', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1987
# ['film', 'direction', 'story', 'screenplay', 'main actors']
# 2
# ['opening', 'opening.1', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1988
# ['film', 'direction', 'story', 'screenplay', 'main actors', 'unnamed: 5']
# 2
# ['film', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1989
# ['film', 'direction', 'story', 'screenplay', 'main actors']
# 3
# ['opening', 'opening.1', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1990
# ['title', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1990
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 2
# ['title', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1991
# ['title', 'director', 'story', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1991
# 2
# ['title', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1992
# ['title', 'director', 'story', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1992
# 1
# ['title', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1993
# 2
# ['title', 'director', 'cast', 'screenplay']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1994
# ['title', 'director', 'story', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1994
# 2
# ['title', 'director', 'cast', 'screenplay']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1995
# ['title', 'director', 'story', 'unnamed: 3', 'unnamed: 4']
# 2
# ['opening', 'opening.1', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1996
# ["('month', 'month')", "('release date', 'release date')", "('no.', 'no.')", "('title', 'title')", "('director', 'director')", "('original title', 'film')", "('original title', 'language')", "('cast', 'cast')", "('music director', 'music director')", "('ref', 'ref')"]
# 2
# ['opening', 'opening.1', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1997
# ['title', 'director', 'music', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1997
# 2
# ['opening', 'opening.1', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1998
# ["('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 1
# ['opening', 'opening.1', 'film', 'cast', 'director', 'music director', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_1999
# 2
# ['title', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2001
# ['title', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2001
# 3
# ['opening', 'opening.1', 'sl. no.', 'film', 'director', 'cast', 'notes']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2002
# ['title', 'director', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2002
# ["('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 2
# ['title', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2003
# ["('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 2
# ['title', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2004
# ["('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 2
# ['title', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2005
# ["('openings', 'openings')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 2
# ['mo', 'unnamed: 1', 'title', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2006
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 2
# ['mo', 'title', 'director', 'screenplay', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2007
# ["('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 2
# ['mo', 'title', 'director', 'producer', 'cast']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2008
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# 3
# ['title', 'director', 'cast', 'genre']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2009
# ['title', 'director', 'cast', 'genre']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2009
# ['month', 'date', 'name', 'age', 'profession', 'notable films']
# 3
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2010
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# ['0', '1', '2', '3', '4', '5']
# 1
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2011
# 1
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2012
# 3
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2013
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('genre', 'genre')", "('ref.', 'ref.')"]
# ['0', '1', '2', '3', '4', '5']
# 2
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2014
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'cast')", "('original film', 'ref.')", "('cast', 'unnamed: 5_level_1')", "('ref.', 'unnamed: 6_level_1')"]
# 3
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2015
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# ['month', 'date', 'name', 'age', 'profession', 'notable films']
# 3
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2016
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# ['month', 'date', 'name', 'age', 'profession', 'notable films']
# 3
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production house', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2017
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# ['month', 'date', 'name', 'age', 'profession', 'notable films', 'ref.']
# 3
# ['opening', 'opening.1', 'title', 'director', 'cast', 'genre', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2018
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# ['month', 'date', 'name', 'age', 'profession', 'notable films', 'ref.']
# 3
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production house', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2019
# ["('opening', 'opening')", "('title', 'title')", "('director(s)', 'director(s)')", "('original film', 'film')", "('original film', 'language')", "('cast', 'cast')", "('ref.', 'ref.')"]
# ['month', 'date', 'name', 'age', 'profession', 'notable films', 'ref.']
# 1
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production house', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2020
# 4
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production house', 'ref', 'ott']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2021
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production house', 'ref', 'ott']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2021
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production house', 'ref', 'ott']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2021
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production house', 'ref', 'ott']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2021
# 4
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2022
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2022
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2022
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2022
# 5
# ['rank', 'title', 'production company', 'gross', 'ref']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2023
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2023
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2023
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2023
# 5
# ['rank', 'title', 'production company', 'worldwide gross', 'ref']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2024
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2024
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2024
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2024
# 4
# ['rank', 'title', 'production company', 'worldwide gross', 'ref']
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2025
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2025
# ['opening', 'opening.1', 'title', 'director', 'cast', 'production company / studio', 'ref']
# https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_2025

# %%
df = pd.concat(movies, ignore_index=True)

# %%
df
# Out:
#                Movies    Year             Director               Story  \
# 0      Vigathakumaran  1928.0         J. C. Daniel        J. C. Daniel
# 1     Marthanda Varma  1933.0            P. V. Rao  C. V. Raman Pillai
# 2               Balan  1938.0           S. Nottani   Sundaram Pillai A
# 3          Gnanambika  1940.0           S. Nottani  C. Madhavan Pillai
# 4            Prahlada  1941.0       K. Subramanyam           Mythology
# ...               ...     ...                  ...                 ...
# 5993              NaN  2025.0       Sreedev Kappur                 NaN
# 5994              NaN  2025.0          Sai Krishna                 NaN
# 5995              NaN  2025.0     Sathyan Anthikad                 NaN
# 5996              NaN  2025.0     Fazil Faziludeen                 NaN
# 5997              NaN  2025.0  Vineeth Sreenivasan                 NaN
#
#                       Screenplay  \
# 0                   J. C. Daniel
# 1                      P. V. Rao
# 2     Muthukulam Raghavan Pillai
# 3           S. P. Pillai (debut)
# 4          N. P. Chellappan Nair
# ...                          ...
# 5993                         NaN
# 5994                         NaN
# 5995                         NaN
# 5996                         NaN
# 5997                         NaN
#
#                                             Main actors   Language  \
# 0                              J. C. Daniel, P. K. Rosy  Malayalam
# 1               Jaidev, A. V. P. Menon, Devaki, Padmini  Malayalam
# 2          K. K. Aroor, Alleppey Vincent, M. K. Kamalam  Malayalam
# 3     K. K. Aroor, Alleppey Vincent, Sebastian Kunju...  Malayalam
# 4     T. K. Balachandran, N. P. Chellappan Nair, Gur...  Malayalam
# ...                                                 ...        ...
# 5993                                                NaN  Malayalam
# 5994                                                NaN  Malayalam
# 5995                                                NaN  Malayalam
# 5996                                                NaN  Malayalam
# 5997                                                NaN  Malayalam
#
#                                                     url  No. Movie  ...  \
# 0     https://en.wikipedia.org/wiki/List_of_Malayala...  NaN   NaN  ...
# 1     https://en.wikipedia.org/wiki/List_of_Malayala...  NaN   NaN  ...
# 2     https://en.wikipedia.org/wiki/List_of_Malayala...  NaN   NaN  ...
# 3     https://en.wikipedia.org/wiki/List_of_Malayala...  NaN   NaN  ...
# 4     https://en.wikipedia.org/wiki/List_of_Malayala...  NaN   NaN  ...
# ...                                                 ...  ...   ...  ...
# 5993  https://en.wikipedia.org/wiki/List_of_Malayala...  NaN   NaN  ...
# 5994  https://en.wikipedia.org/wiki/List_of_Malayala...  NaN   NaN  ...
# 5995  https://en.wikipedia.org/wiki/List_of_Malayala...  NaN   NaN  ...
# 5996  https://en.wikipedia.org/wiki/List_of_Malayala...  NaN   NaN  ...
# 5997  https://en.wikipedia.org/wiki/List_of_Malayala...  NaN   NaN  ...
#
#      Music Director Lyricist   Mo Unnamed: 1 Producer  Genre         Ref  \
# 0               NaN      NaN  NaN        NaN      NaN    NaN         NaN
# 1               NaN      NaN  NaN        NaN      NaN    NaN         NaN
# 2               NaN      NaN  NaN        NaN      NaN    NaN         NaN
# 3               NaN      NaN  NaN        NaN      NaN    NaN         NaN
# 4               NaN      NaN  NaN        NaN      NaN    NaN         NaN
# ...             ...      ...  ...        ...      ...    ...         ...
# 5993            NaN      NaN  NaN        NaN      NaN    NaN  [176][177]
# 5994            NaN      NaN  NaN        NaN      NaN    NaN       [178]
# 5995            NaN      NaN  NaN        NaN      NaN    NaN       [179]
# 5996            NaN      NaN  NaN        NaN      NaN    NaN       [180]
# 5997            NaN      NaN  NaN        NaN      NaN    NaN       [181]
#
#      Production house  OTT      Production Company / Studio
# 0                 NaN  NaN                              NaN
# 1                 NaN  NaN                              NaN
# 2                 NaN  NaN                              NaN
# 3                 NaN  NaN                              NaN
# 4                 NaN  NaN                              NaN
# ...               ...  ...                              ...
# 5993              NaN  NaN                 Kalarikkal Films
# 5994              NaN  NaN                 Vinreels Digital
# 5995              NaN  NaN                Aashirvad Cinemas
# 5996              NaN  NaN                Spire Productions
# 5997              NaN  NaN  Habit of Life Merryland Cinemas
#
# [5998 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['Movies', 'Year', 'Director', 'Story', 'Screenplay', 'Main actors',
#        'Language', 'url', 'No.', 'Movie', 'Date', 'Direction', 'Music',
#        'Opening', 'Opening.1', 'Sl. no.', 'Title', 'Cast(s)', 'Music director',
#        'Film', 'Cast', 'Notes', 'Basic Language', 'Sl. No.', 'Music Director',
#        'Lyricist', 'Mo', 'Unnamed: 1', 'Producer', 'Genre', 'Ref',
#        'Production house', 'OTT', 'Production Company / Studio'],
#       dtype='object')

# %%
# keep non null values from all columns, row by row
df['music'] = df[['Music', 'Music director', 'Music Director']].bfill(axis=1).iloc[:, 0]

# %%
df['title'] = df[['Movies', 'Movie', 'Title','Film']].bfill(axis=1).iloc[:, 0]
df['production'] = df[['Production house', 'Production Company / Studio']].bfill(axis=1).iloc[:, 0]
df['cast'] = df[['Main actors', 'Cast(s)', 'Cast']].bfill(axis=1).iloc[:, 0]
df['year'] = df[['Year', 'Date', 'Music Director']].bfill(axis=1).iloc[:, 0]

# %%
df = df[['title', 'Director', 'cast', 'year', 'Language', 'url', 'Producer','Genre', 'production', 'music', 'Ref']]

# %%
df.columns = ['Title', 'Director', 'Cast', 'Year', 'Language', 'url', 'Producer','Genre', 'production', 'music', 'ref']

# %%
df.to_csv("malayalam_movies_1928_2025.csv", index=False)
