# %% [markdown]
# ### Scraping Telugu movies from Wiki

# %%
# import required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# year 1930-39
url = "https://en.wikipedia.org/wiki/List_of_Telugu_films_of_the_1930s"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
tables = soup.find_all('table', {'class': 'wikitable'})
movies = []
for table in tables:
    df = pd.read_html(str(table))[0]
    col_names = [str(col).lower().strip() for col in df.columns]
    if "title" in col_names and "director" in col_names and 'cast' in col_names:
        df['Year'] = '1930s'
        df['Language'] = "Telugu"
        df['url'] = url
        movies.append(df)
        print(url)
# Out:
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_the_1930s

# %%
# year 1940 - 2025
years = list(range(1940, 2026))
for year in years:
    url = "https://en.wikipedia.org/wiki/List_of_Telugu_films_of_" + str(year)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    tables = soup.find_all('table', {'class': 'wikitable'})
    for table in tables:
        df = pd.read_html(str(table))[0]
        col_names = [str(col).lower().strip() for col in df.columns]
        if "title" in col_names and "director" in col_names and 'cast' in col_names:
            df['Year'] = year
            df['Language'] = "Telugu"
            df['url'] = url
            movies.append(df)
            print(url)
# Out:
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1940
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1941
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1942
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1943
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1944
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1945
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1946
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1947
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1948
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1949
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1950
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1951
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1952
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1953
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1954
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1955
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1956
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1957
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1958
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1959
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1960
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1961
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1962
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1963
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1964
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1965
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1966
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1967
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1968
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1969
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1970
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1971
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1972
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1973
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1974
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1975
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1976
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1977
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1978
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1979
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1980
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1981
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1982
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1982
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1982
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1982
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1983
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1984
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1985
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1986
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1986
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1986
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1986
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1987
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1987
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1987
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1987
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1988
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1989
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1990
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1991
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1992
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1993
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1994
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1995
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1996
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1997
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1998
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1999
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_1999
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2000
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2000
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2001
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2001
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2001
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2002
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2002
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2003
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2003
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2004
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2004
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2005
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2005
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2006
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2007
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2008
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2008
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2009
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2010
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2010
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2011
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2011
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2012
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2012
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2013
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2013
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2014
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2014
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2015
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2015
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2016
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2016
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2017
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2017
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2018
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2018
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2019
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2019
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2020
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2020
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2020
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2021
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2021
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2021
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2021
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2022
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2022
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2022
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2022
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2023
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2023
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2023
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2023
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2024
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2024
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2024
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2024
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2025
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2025
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2025
# https://en.wikipedia.org/wiki/List_of_Telugu_films_of_2025

# %%
final_df = pd.concat(movies, ignore_index=True)

# %%
final_df.head()
# Out:
#                             Title          Director                Production  \
# 0                            1931              1931                      1931
# 1                         Kalidas       H. M. Reddy        Imperial Movi-Tone
# 2                            1932              1932                      1932
# 3                 Bhakta Prahlada       H. M. Reddy  Sri Krishna Film Company
# 4  Sri Rama Paduka Pattabhishekam  Sarvottam Badami           Sagar Movietone
#
#                                                 Cast          Release  \
# 0                                               1931             1931
# 1  T. P. Rajalakshmi, P. G. Venkatesan, L. V. Prasad  31 October 1931
# 2                                               1932             1932
# 3  Venkata Subbaiah Municipalle, Surabhi Kamalaba...  6 February 1932
# 4  C. S. R. Anjaneyulu, Surabhi Kamalabai, Yadava...              NaN
#
#   Unnamed: 5  Unnamed: 6   Year Language  \
# 0     1931.0         NaN  1930s   Telugu
# 1        NaN         NaN  1930s   Telugu
# 2     1932.0      1932.0  1930s   Telugu
# 3        NaN         NaN  1930s   Telugu
# 4        NaN         NaN  1930s   Telugu
#
#                                                  url  ... Source Sources  \
# 0  https://en.wikipedia.org/wiki/List_of_Telugu_f...  ...    NaN     NaN
# 1  https://en.wikipedia.org/wiki/List_of_Telugu_f...  ...    NaN     NaN
# 2  https://en.wikipedia.org/wiki/List_of_Telugu_f...  ...    NaN     NaN
# 3  https://en.wikipedia.org/wiki/List_of_Telugu_f...  ...    NaN     NaN
# 4  https://en.wikipedia.org/wiki/List_of_Telugu_f...  ...    NaN     NaN
#
#   Production studio Opening Opening.1  Ref Studio Production house  \
# 0               NaN     NaN       NaN  NaN    NaN              NaN
# 1               NaN     NaN       NaN  NaN    NaN              NaN
# 2               NaN     NaN       NaN  NaN    NaN              NaN
# 3               NaN     NaN       NaN  NaN    NaN              NaN
# 4               NaN     NaN       NaN  NaN    NaN              NaN
#
#   Production house Production House
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN
#
# [5 rows x 31 columns]

# %%
final_df.columns
# Out:
# Index(['Title', 'Director', 'Production', 'Cast', 'Release', 'Unnamed: 5',
#        'Unnamed: 6', 'Year', 'Language', 'url', 'Producer', 'Genre', 'Ref.',
#        'Composer', 'Release Date', 'Production company', 'Music',
#        'Music Director', 'Unnamed: 4', 'Music director', 'Notes', 'Source',
#        'Sources', 'Production studio', 'Opening', 'Opening.1', 'Ref', 'Studio',
#        'Production house', 'Production house', 'Production House'],
#       dtype='object')

# %%
# keep non-null values from all columns, row by row
final_df['production'] = final_df[['Production', 'Production company', 'Production studio', 'Studio','Production house','Production House']].bfill(axis=1).iloc[:, 0]
final_df['music'] = final_df[['Composer', 'Music', 'Music Director', 'Music director']].bfill(axis=1).iloc[:, 0]
final_df['release'] = final_df[['Release', 'Release Date', 'Opening', 'Opening.1']].bfill(axis=1).iloc[:, 0]
final_df['ref'] = final_df[['Ref.', 'Ref', 'Source', 'Sources']].bfill(axis=1).iloc[:, 0]

# %%
# once merged drop extras
final_df.drop(columns=['Production', 'Production company', 'Production studio', 'Studio','Production house','Production House'], inplace=True)
final_df.drop(columns=['Composer', 'Music', 'Music Director', 'Music director'], inplace=True)
final_df.drop(columns=['Release', 'Release Date', 'Opening', 'Opening.1'], inplace=True)
final_df.drop(columns=['Ref.', 'Ref', 'Source', 'Sources'], inplace=True)

# %%
final_df.columns
# Out:
# Index(['Title', 'Director', 'Cast', 'Year', 'Language', 'url', 'Producer',
#        'Genre', 'Production house', 'production', 'music', 'release', 'ref'],
#       dtype='object')

# %%
final_df.drop(columns=['Unnamed: 5','Unnamed: 6','Unnamed: 4','Notes'],inplace=True)

# %%
df = final_df[['Title', 'Director', 'Cast', 'Year', 'Language', 'url', 'Producer','Genre', 'production', 'music', 'release', 'ref']]

# %%
# Drop any column where >90% of values are NaN:
null_threshold = 0.9
df = df.loc[:, df.isnull().mean() < null_threshold]

# %%
df.isnull().sum()
# Out:
# Title           28
# Director       213
# Cast           140
# Year             0
# Language         0
# url              0
# production    2852
# music         4084
# release       1921
# ref           3234
# dtype: int64

# %%
df.to_csv("telugu_movies_1930_2025.csv", index=False)
